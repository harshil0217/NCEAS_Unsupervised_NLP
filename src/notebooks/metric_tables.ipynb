# %%
import pandas as pd

# %%
def load_and_aggregate(path: str) -> pd.DataFrame:
    """
    Load a clustering scores CSV, drop 'level', aggregate by
    (embedding_model, reduction_method, cluster_method), and sort by AMI descending.
    """
    df = pd.read_csv(path)
    df = df.drop(columns=["level"])
    df = df.groupby(["embedding_model", "reduction_method", "cluster_method"]).mean().reset_index()
    df = df.sort_values(by="Dendrogram_Purity", ascending=False)
    return df

# %%
amz = load_and_aggregate("../results/amazon_clustering_scores.csv")

# %%
amz.head(8)
# Out:
#                            embedding_model reduction_method cluster_method  \
# 9                Qwen/Qwen3-Embedding-0.6B             UMAP  Agglomerative
# 24  sentence-transformers/all-MiniLM-L6-v2             UMAP  Agglomerative
# 6                Qwen/Qwen3-Embedding-0.6B           PaCMAP  Agglomerative
# 0                Qwen/Qwen3-Embedding-0.6B              PCA  Agglomerative
# 1                Qwen/Qwen3-Embedding-0.6B              PCA             DC
# 3                Qwen/Qwen3-Embedding-0.6B            PHATE  Agglomerative
# 21  sentence-transformers/all-MiniLM-L6-v2           PaCMAP  Agglomerative
# 4                Qwen/Qwen3-Embedding-0.6B            PHATE             DC
#
#           FM      Rand       ARI       AMI  Dendrogram_Purity    LCA_F1
# 9   0.334619  0.874560  0.236451  0.437789           0.399751  0.390800
# 24  0.345811  0.896388  0.263851  0.447447           0.382710  0.388949
# 6   0.321158  0.914143  0.254581  0.439983           0.375476  0.366320
# 0   0.290785  0.912438  0.226611  0.434517           0.365180  0.353065
# 1   0.278318  0.907540  0.210501  0.423820           0.351249  0.348311
# 3   0.267919  0.903684  0.203450  0.395044           0.347253  0.349036
# 21  0.283174  0.903287  0.211272  0.406611           0.344918  0.354714
# 4   0.276783  0.917273  0.218868  0.389211           0.344210  0.343263

# %%
db = load_and_aggregate('../results/db_clustering_scores.csv')

# %%
db.head(10)
# Out:
#                            embedding_model reduction_method cluster_method  \
# 9                Qwen/Qwen3-Embedding-0.6B             UMAP  Agglomerative
# 11               Qwen/Qwen3-Embedding-0.6B             UMAP        HDBSCAN
# 3                Qwen/Qwen3-Embedding-0.6B            PHATE  Agglomerative
# 14               Qwen/Qwen3-Embedding-0.6B             tSNE        HDBSCAN
# 6                Qwen/Qwen3-Embedding-0.6B           PaCMAP  Agglomerative
# 12               Qwen/Qwen3-Embedding-0.6B             tSNE  Agglomerative
# 24  sentence-transformers/all-MiniLM-L6-v2             UMAP  Agglomerative
# 26  sentence-transformers/all-MiniLM-L6-v2             UMAP        HDBSCAN
# 21  sentence-transformers/all-MiniLM-L6-v2           PaCMAP  Agglomerative
# 5                Qwen/Qwen3-Embedding-0.6B            PHATE        HDBSCAN
#
#           FM      Rand       ARI       AMI  Dendrogram_Purity
# 9   0.320183  0.484340  0.028777  0.301775           0.596428
# 11  0.318361  0.506487  0.032951  0.306444           0.591885
# 3   0.297300  0.269110  0.013703  0.147901           0.569888
# 14  0.332081  0.606531  0.048430  0.374948           0.569346
# 6   0.369014  0.679861  0.153019  0.471909           0.565362
# 12  0.305177  0.440131  0.019470  0.282355           0.561693
# 24  0.296422  0.289890  0.010438  0.146699           0.551670
# 26  0.299468  0.371121  0.007980  0.157611           0.550011
# 21  0.302563  0.610123  0.093406  0.382574           0.546385
# 5   0.296267  0.275631  0.012228  0.152909           0.545388

# %%
rcv1 = load_and_aggregate("../results/rcv1_clustering_scores.csv")

# %%
rcv1.head(8)
# Out:
#                            embedding_model reduction_method cluster_method  \
# 12               Qwen/Qwen3-Embedding-0.6B             tSNE  Agglomerative
# 13               Qwen/Qwen3-Embedding-0.6B             tSNE             DC
# 4                Qwen/Qwen3-Embedding-0.6B            PHATE             DC
# 19  sentence-transformers/all-MiniLM-L6-v2            PHATE             DC
# 0                Qwen/Qwen3-Embedding-0.6B              PCA  Agglomerative
# 3                Qwen/Qwen3-Embedding-0.6B            PHATE  Agglomerative
# 27  sentence-transformers/all-MiniLM-L6-v2             tSNE  Agglomerative
# 16  sentence-transformers/all-MiniLM-L6-v2              PCA             DC
#
#           FM      Rand       ARI       AMI  Dendrogram_Purity    LCA_F1
# 12  0.211960  0.909768  0.148813  0.387684           0.477362  0.424239
# 13  0.184559  0.911941  0.119254  0.356801           0.475062  0.420812
# 4   0.223092  0.914764  0.152303  0.413046           0.473390  0.413414
# 19  0.211913  0.914598  0.140813  0.413746           0.466753  0.406401
# 0   0.223574  0.916038  0.149279  0.439375           0.458571  0.423778
# 3   0.206741  0.912882  0.139190  0.420507           0.440325  0.395884
# 27  0.206316  0.908313  0.144337  0.364984           0.438556  0.390928
# 16  0.217927  0.915456  0.144692  0.426161           0.437982  0.404600

# %%
wos = load_and_aggregate("../results/wos_clustering_scores.csv")

# %%
wos.head(8)
# Out:
#                            embedding_model reduction_method cluster_method  \
# 24  sentence-transformers/all-MiniLM-L6-v2             UMAP  Agglomerative
# 9                Qwen/Qwen3-Embedding-0.6B             UMAP  Agglomerative
# 21  sentence-transformers/all-MiniLM-L6-v2           PaCMAP  Agglomerative
# 10               Qwen/Qwen3-Embedding-0.6B             UMAP             DC
# 27  sentence-transformers/all-MiniLM-L6-v2             tSNE  Agglomerative
# 6                Qwen/Qwen3-Embedding-0.6B           PaCMAP  Agglomerative
# 0                Qwen/Qwen3-Embedding-0.6B              PCA  Agglomerative
# 11               Qwen/Qwen3-Embedding-0.6B             UMAP        HDBSCAN
#
#           FM      Rand       ARI       AMI  Dendrogram_Purity    LCA_F1
# 24  0.349825  0.871377  0.258573  0.449596           0.353315  0.317892
# 9   0.351070  0.868016  0.254833  0.452125           0.349279  0.329861
# 21  0.318495  0.899370  0.258473  0.450447           0.342972  0.308878
# 10  0.310862  0.895164  0.248233  0.442665           0.334266  0.310476
# 27  0.324308  0.896791  0.262700  0.434128           0.331265  0.305535
# 6   0.308077  0.894687  0.245385  0.448003           0.327443  0.316784
# 0   0.301856  0.894840  0.239176  0.429231           0.326418  0.300573
# 11  0.270658  0.357651  0.007267  0.110700           0.316448  0.297629

# %%
arxiv = load_and_aggregate("../results/arxiv_clustering_scores.csv")

# %%
arxiv.head(10)
# Out:
#                            embedding_model reduction_method cluster_method  \
# 21  sentence-transformers/all-MiniLM-L6-v2           PaCMAP  Agglomerative
# 6                Qwen/Qwen3-Embedding-0.6B           PaCMAP  Agglomerative
# 9                Qwen/Qwen3-Embedding-0.6B             UMAP  Agglomerative
# 24  sentence-transformers/all-MiniLM-L6-v2             UMAP  Agglomerative
# 18  sentence-transformers/all-MiniLM-L6-v2            PHATE  Agglomerative
# 8                Qwen/Qwen3-Embedding-0.6B           PaCMAP        HDBSCAN
# 11               Qwen/Qwen3-Embedding-0.6B             UMAP        HDBSCAN
# 3                Qwen/Qwen3-Embedding-0.6B            PHATE  Agglomerative
# 20  sentence-transformers/all-MiniLM-L6-v2            PHATE        HDBSCAN
# 23  sentence-transformers/all-MiniLM-L6-v2           PaCMAP        HDBSCAN
#
#           FM      Rand       ARI       AMI  Dendrogram_Purity
# 21  0.617208  0.648947  0.436474  0.450185           0.725841
# 6   0.619073  0.650489  0.441558  0.459924           0.721431
# 9   0.528719  0.360595 -0.000068 -0.000164           0.709834
# 24  0.528872  0.360670  0.000013 -0.000001           0.706251
# 18  0.529163  0.362189  0.000264  0.001503           0.660105
# 8   0.618075  0.651712  0.441163  0.460043           0.655084
# 11  0.527250  0.366902 -0.000353  0.002623           0.651046
# 3   0.528813  0.362604  0.000026  0.001833           0.645293
# 20  0.529028  0.365017  0.000397  0.003101           0.641075
# 23  0.617084  0.649797  0.436523  0.450345           0.639441

# %%
amz_herc = pd.read_csv("../results/amazon_herc_clustering_scores.csv")
amz_herc
# Out:
#                      Embedding Model Name        FM      Rand       ARI  \
# 0               Qwen/Qwen3-Embedding-0.6B  0.212096  0.664929 -0.000421
# 1  sentence-transformers/all-MiniLM-L6-v2  0.212096  0.664929 -0.000421
#
#        AMI
# 0  0.00032
# 1  0.00032

# %%
arxiv_herc =  pd.read_csv("../results/arxiv_herc_clustering_scores.csv")

# %%
arxiv_herc
# Out:
#                      Embedding Model Name        FM     Rand       ARI  \
# 0               Qwen/Qwen3-Embedding-0.6B  0.579696  0.50367 -0.000128
# 1  sentence-transformers/all-MiniLM-L6-v2  0.579696  0.50367 -0.000128
#
#         AMI
# 0 -0.000027
# 1 -0.000027

# %%
db_herc =  pd.read_csv("../results/db_herc_clustering_scores.csv")

# %%
db_herc
# Out:
#                      Embedding Model Name        FM      Rand       ARI  \
# 0               Qwen/Qwen3-Embedding-0.6B  0.213583  0.624913  0.000316
# 1  sentence-transformers/all-MiniLM-L6-v2  0.213583  0.624913  0.000316
#
#         AMI
# 0  0.000057
# 1  0.000057

# %%
rcv1_herc =  pd.read_csv("../results/rcv1_herc_clustering_scores.csv")
rcv1_herc
# Out:
#                      Embedding Model Name        FM      Rand       ARI  \
# 0               Qwen/Qwen3-Embedding-0.6B  0.045611  0.895315 -0.001184
# 1  sentence-transformers/all-MiniLM-L6-v2  0.045611  0.895315 -0.001184
#
#         AMI
# 0  0.001209
# 1  0.001209

# %%
wos_herc =  pd.read_csv("../results/wos_herc_clustering_scores.csv")
wos_herc
# Out:
#                      Embedding Model Name       FM      Rand       ARI  \
# 0               Qwen/Qwen3-Embedding-0.6B  0.17507  0.710811 -0.000139
# 1  sentence-transformers/all-MiniLM-L6-v2  0.17507  0.710811 -0.000139
#
#         AMI
# 0 -0.000052
# 1 -0.000052
