# %%
import os
import sys
import pandas as pd
import nltk
from nltk.corpus import reuters

# %%
target_folder = "src"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

current_dir = os.getcwd()
while os.path.basename(current_dir) != target_folder:
    parent_dir = os.path.abspath(os.path.join(current_dir, ".."))
    if parent_dir == current_dir:
        raise FileNotFoundError(f"{target_folder} not found in the directory tree.")
    current_dir = parent_dir

os.chdir(current_dir)
sys.path.insert(0, current_dir)

theme = "rcv1"
t = 7.0
max_sub = 5
depth = 3
synonyms = 0
add_noise = 0.0
branching = "balanced"

DATA_GEN_DIR = "data/rcv1"
os.makedirs(DATA_GEN_DIR, exist_ok=True)

filename = f'{DATA_GEN_DIR}/rcv1.csv'

def main():
    print("Fetching NLTK Reuters...")
    nltk.download('reuters')
    
    file_ids = reuters.fileids()
    data_list = []
    for f in file_ids:
        text = reuters.raw(f).replace('\n', ' ').strip()
        cats = reuters.categories(f)
        if len(cats) < 2: continue
        
        print(cats)

        data_list.append({
            "item_id": f,
            "topic": text,
            "category 0": cats[0],
            "category 1": cats[1],
        })

    df = pd.DataFrame(data_list)
    df.to_csv(filename, index=False)
    print(f"Success! Data saved to {filename}")

if __name__ == "__main__":
    main()
# Out:
# Fetching NLTK Reuters...
# [nltk_data] Downloading package reuters to
# [nltk_data]     /home/harshil0216/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# ['crude', 'nat-gas']
# ['corn', 'grain', 'rice', 'rubber', 'sugar', 'tin', 'trade']
# ['palm-oil', 'veg-oil']
# ['coffee', 'lumber', 'palm-oil', 'rubber', 'veg-oil']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['acq', 'copper']
# ['carcass', 'corn', 'grain', 'livestock', 'oilseed', 'rice', 'soybean', 'trade']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['gas', 'lead']
# ['interest', 'money-fx']
# ['cpi', 'gnp']
# ['oilseed', 'palm-oil', 'soy-oil', 'soybean', 'veg-oil']
# ['dlr', 'money-fx', 'yen']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed', 'wheat']
# ['acq', 'crude', 'earn', 'pet-chem']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['oilseed', 'rapeseed']
# ['grain', 'wheat']
# ['dlr', 'interest', 'money-fx']
# ['crude', 'earn']
# ['carcass', 'livestock']
# ['iron-steel', 'trade']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['l-cattle', 'livestock']
# ['iron-steel', 'trade']
# ['crude', 'nat-gas']
# ['crude', 'gas']
# ['corn', 'grain', 'veg-oil', 'wheat']
# ['crude', 'gas']
# ['crude', 'gas']
# ['interest', 'money-fx']
# ['grain', 'rice']
# ['acq', 'trade']
# ['money-fx', 'trade']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['palladium', 'platinum', 'strategic-metal']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['money-fx', 'trade']
# ['dlr', 'money-fx']
# ['grain', 'wheat']
# ['grain', 'groundnut-oil', 'lin-oil', 'meal-feed', 'oilseed', 'rape-oil', 'sorghum', 'soy-oil', 'sun-meal', 'sun-oil', 'veg-oil', 'wheat']
# ['crude', 'heat']
# ['interest', 'money-fx']
# ['grain', 'ship']
# ['hog', 'livestock']
# ['oilseed', 'soybean']
# ['interest', 'money-fx']
# ['dlr', 'yen']
# ['interest', 'money-supply', 'trade']
# ['grain', 'rice', 'sorghum', 'wheat']
# ['grain', 'wheat']
# ['groundnut', 'oilseed']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['barley', 'corn', 'grain', 'wheat']
# ['dlr', 'money-fx']
# ['carcass', 'livestock']
# ['bop', 'trade']
# ['corn', 'grain']
# ['barley', 'grain']
# ['barley', 'corn', 'grain', 'wheat']
# ['dlr', 'money-fx']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['dlr', 'money-fx']
# ['ship', 'sugar']
# ['grain', 'ship']
# ['corn', 'grain']
# ['oilseed', 'rapeseed']
# ['coffee', 'trade']
# ['grain', 'ship']
# ['ship', 'sugar']
# ['barley', 'grain', 'ship', 'wheat']
# ['coffee', 'trade']
# ['soy-oil', 'veg-oil']
# ['carcass', 'livestock']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['cotton', 'grain', 'meal-feed', 'oilseed', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil', 'wheat']
# ['corn', 'grain']
# ['corn', 'grain', 'wheat']
# ['corn', 'grain', 'wheat']
# ['grain', 'wheat']
# ['oilseed', 'soybean']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['barley', 'corn', 'cotton', 'cotton-oil', 'grain', 'meal-feed', 'oat', 'oilseed', 'rice', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil']
# ['grain', 'wheat']
# ['barley', 'corn', 'cotton', 'grain', 'meal-feed', 'oat', 'oilseed', 'rice', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil', 'wheat']
# ['corn', 'grain']
# ['corn', 'cotton', 'grain', 'meal-feed', 'oilseed', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['meal-feed', 'soy-meal']
# ['corn', 'grain']
# ['corn', 'cotton', 'grain', 'meal-feed', 'oilseed', 'rice', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil', 'wheat']
# ['corn', 'grain']
# ['corn', 'grain', 'meal-feed', 'soy-meal', 'wheat']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed', 'wheat']
# ['oilseed', 'soybean']
# ['meal-feed', 'soy-meal']
# ['soy-oil', 'veg-oil']
# ['grain', 'wheat']
# ['grain', 'rice']
# ['grain', 'ship']
# ['barley', 'corn', 'grain', 'oat', 'sorghum', 'wheat']
# ['meal-feed', 'oilseed', 'soy-meal', 'soybean']
# ['grain', 'meal-feed', 'oilseed', 'veg-oil']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['acq', 'crude', 'nat-gas']
# ['cotton', 'gold', 'grain', 'livestock', 'money-fx', 'silver']
# ['corn', 'grain']
# ['grain', 'ship']
# ['crude', 'ship']
# ['dlr', 'interest', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['corn', 'grain', 'oat', 'sorghum', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'rice']
# ['rape-oil', 'soy-oil', 'veg-oil']
# ['interest', 'money-supply']
# ['corn', 'grain', 'rice']
# ['dlr', 'money-fx']
# ['bop', 'cpi', 'gnp']
# ['dlr', 'money-fx']
# ['cpi', 'income', 'retail', 'trade', 'wpi']
# ['grain', 'wheat']
# ['corn', 'grain', 'groundnut', 'oilseed', 'rice']
# ['bop', 'cpi', 'gnp', 'jobs']
# ['interest', 'money-fx']
# ['gold', 'platinum']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['money-fx', 'trade']
# ['palm-oil', 'veg-oil']
# ['bop', 'cpi', 'gnp']
# ['gold', 'platinum', 'silver']
# ['money-supply', 'reserves']
# ['hog', 'livestock']
# ['grain', 'meal-feed', 'oilseed']
# ['cpi', 'gnp', 'money-supply']
# ['grain', 'wheat']
# ['acq', 'alum']
# ['palm-oil', 'veg-oil']
# ['crude', 'ship']
# ['acq', 'carcass', 'livestock']
# ['interest', 'money-fx']
# ['acq', 'earn']
# ['oilseed', 'rapeseed']
# ['crude', 'nat-gas']
# ['acq', 'earn']
# ['acq', 'livestock']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['carcass', 'livestock']
# ['interest', 'money-fx']
# ['crude', 'nat-gas']
# ['grain', 'rice']
# ['corn', 'grain']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['soybean', 'veg-oil']
# ['grain', 'sorghum']
# ['grain', 'trade']
# ['corn', 'grain']
# ['bop', 'trade']
# ['reserves', 'trade']
# ['carcass', 'orange', 'rice', 'trade']
# ['grain', 'trade']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-supply']
# ['fuel', 'gas']
# ['grain', 'orange', 'sugar']
# ['coconut', 'coconut-oil', 'copra-cake', 'meal-feed', 'palm-oil', 'veg-oil']
# ['lead', 'strategic-metal', 'zinc']
# ['lead', 'strategic-metal', 'zinc']
# ['nat-gas', 'ship']
# ['corn', 'grain', 'wheat']
# ['copper', 'corn', 'grain', 'sugar']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['acq', 'pet-chem']
# ['acq', 'pet-chem']
# ['dfl', 'dmk', 'interest', 'money-fx']
# ['gold', 'silver']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['cocoa', 'coffee']
# ['crude', 'nat-gas']
# ['lumber', 'trade']
# ['alum', 'copper', 'gold', 'silver']
# ['corn', 'grain', 'soybean', 'wheat']
# ['acq', 'pet-chem']
# ['crude', 'ship']
# ['grain', 'oilseed', 'wheat']
# ['barley', 'grain']
# ['barley', 'grain']
# ['lead', 'strategic-metal', 'zinc']
# ['lead', 'strategic-metal', 'zinc']
# ['acq', 'hog']
# ['dlr', 'money-fx', 'trade']
# ['gnp', 'interest']
# ['acq', 'crude']
# ['crude', 'ship']
# ['acq', 'crude', 'nat-gas']
# ['bop', 'trade']
# ['bop', 'trade']
# ['grain', 'ship', 'wheat']
# ['grain', 'rice', 'wheat']
# ['interest', 'reserves']
# ['cpi', 'gnp']
# ['acq', 'cocoa']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['gold', 'platinum', 'silver']
# ['barley', 'grain']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['ship', 'sugar']
# ['dmk', 'money-fx']
# ['dlr', 'interest', 'money-fx']
# ['crude', 'gas']
# ['meal-feed', 'oilseed', 'soy-meal', 'soybean']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['barley', 'grain']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'oilseed']
# ['crude', 'gas']
# ['acq', 'copper']
# ['acq', 'crude', 'nat-gas']
# ['crude', 'ship']
# ['lead', 'zinc']
# ['crude', 'ship']
# ['grain', 'oilseed', 'rapeseed', 'wheat']
# ['bop', 'trade']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['fuel', 'gas', 'naphtha']
# ['carcass', 'corn', 'grain', 'livestock', 'meal-feed', 'oilseed', 'rapeseed', 'sorghum', 'soy-meal']
# ['platinum', 'silver']
# ['bop', 'trade']
# ['crude', 'ship']
# ['oilseed', 'soybean']
# ['lead', 'ship']
# ['grain', 'rice', 'sugar']
# ['corn', 'grain']
# ['money-fx', 'nzdlr']
# ['grain', 'rice', 'sugar']
# ['crude', 'nat-gas']
# ['income', 'interest', 'jobs', 'reserves']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['coconut-oil', 'cotton-oil', 'palm-oil', 'rape-oil', 'soy-oil', 'sun-oil', 'veg-oil']
# ['reserves', 'trade']
# ['acq', 'crude', 'nat-gas']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['barley', 'grain', 'wheat']
# ['gnp', 'housing', 'income']
# ['corn', 'grain']
# ['corn', 'grain']
# ['bop', 'gnp']
# ['cpi', 'gnp', 'jobs']
# ['gnp', 'jobs']
# ['bop', 'gnp', 'trade']
# ['cpi', 'gnp', 'jobs']
# ['bop', 'gnp', 'jobs']
# ['cpi', 'gnp', 'jobs']
# ['bop', 'cpi', 'gnp']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx', 'money-supply']
# ['money-fx', 'reserves']
# ['grain', 'ship']
# ['oilseed', 'soybean']
# ['grain', 'rice']
# ['bop', 'dlr', 'gnp', 'money-fx', 'yen']
# ['bop', 'gnp']
# ['palm-oil', 'veg-oil']
# ['crude', 'nat-gas']
# ['acq', 'gold']
# ['corn', 'grain', 'rice']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['carcass', 'livestock']
# ['acq', 'nat-gas']
# ['barley', 'grain', 'oat', 'wheat']
# ['oilseed', 'rapeseed']
# ['grain', 'wheat']
# ['alum', 'palm-oil', 'tin', 'veg-oil']
# ['grain', 'meal-feed', 'rice']
# ['crude', 'pet-chem', 'propane']
# ['crude', 'ship']
# ['lead', 'zinc']
# ['bop', 'trade']
# ['lead', 'zinc']
# ['crude', 'fuel', 'naphtha']
# ['money-fx', 'nkr']
# ['money-fx', 'nkr']
# ['grain', 'oilseed', 'rapeseed', 'wheat']
# ['hog', 'livestock', 'trade']
# ['cocoa', 'coffee', 'cotton']
# ['acq', 'oilseed', 'soybean', 'sunseed']
# ['barley', 'grain', 'oat', 'oilseed', 'rapeseed', 'rye', 'sugar', 'wheat']
# ['castor-oil', 'coffee', 'cotton', 'tea', 'trade']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['crude', 'ship']
# ['gold', 'lead', 'silver', 'zinc']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['cotton', 'grain', 'rice']
# ['crude', 'money-fx']
# ['housing', 'interest']
# ['crude', 'naphtha', 'pet-chem']
# ['cotton', 'grain', 'rice', 'trade']
# ['crude', 'ship']
# ['corn', 'grain']
# ['crude', 'ship']
# ['grain', 'rice']
# ['crude', 'ship']
# ['crude', 'nat-gas']
# ['copper', 'gold']
# ['crude', 'ship']
# ['crude', 'ship']
# ['meal-feed', 'oilseed', 'rapeseed', 'soy-meal', 'soybean', 'sunseed']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['jobs', 'trade']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['soybean', 'trade', 'veg-oil']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['carcass', 'trade']
# ['oilseed', 'soybean', 'trade', 'veg-oil']
# ['carcass', 'livestock', 'sugar', 'trade']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['carcass', 'grain', 'livestock', 'trade', 'wheat']
# ['grain', 'oilseed', 'sunseed', 'wheat']
# ['grain', 'wheat']
# ['l-cattle', 'livestock']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['corn', 'grain', 'trade']
# ['interest', 'money-fx']
# ['corn', 'grain', 'meal-feed', 'soy-meal']
# ['crude', 'gas']
# ['grain', 'wheat']
# ['crude', 'ship']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['crude', 'ship']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['coconut-oil', 'oilseed', 'palm-oil', 'palmkernel', 'soybean', 'veg-oil']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['oilseed', 'soybean']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['crude', 'ship']
# ['grain', 'veg-oil']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['corn', 'grain', 'wheat']
# ['gold', 'silver']
# ['carcass', 'hog', 'livestock']
# ['gnp', 'grain', 'ipi']
# ['bop', 'trade']
# ['acq', 'crude', 'nat-gas']
# ['crude', 'ship']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['propane', 'ship']
# ['crude', 'ship']
# ['corn', 'grain', 'rubber', 'sugar']
# ['dlr', 'dmk', 'money-fx']
# ['oilseed', 'veg-oil']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['bop', 'gnp', 'jobs']
# ['alum', 'ship']
# ['cotton', 'grain']
# ['money-fx', 'rand']
# ['dlr', 'dmk', 'money-fx', 'yen']
# ['money-fx', 'nzdlr']
# ['grain', 'rice']
# ['dlr', 'money-fx', 'yen']
# ['acq', 'trade']
# ['crude', 'nat-gas']
# ['cocoa', 'coffee', 'sugar']
# ['iron-steel', 'ship']
# ['acq', 'earn']
# ['dlr', 'money-fx']
# ['acq', 'crude']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['acq', 'crude']
# ['corn', 'grain', 'wheat']
# ['carcass', 'grain', 'livestock', 'sugar']
# ['gnp', 'jobs']
# ['acq', 'corn', 'grain']
# ['acq', 'crude']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['barley', 'corn', 'grain', 'meal-feed', 'oilseed', 'sorghum', 'soy-oil', 'soybean', 'veg-oil', 'wheat']
# ['acq', 'crude', 'nat-gas']
# ['acq', 'earn']
# ['crude', 'nat-gas']
# ['interest', 'money-supply']
# ['coffee', 'crude']
# ['dlr', 'money-fx']
# ['coffee', 'crude', 'grain', 'iron-steel', 'tea', 'trade', 'wheat']
# ['iron-steel', 'trade']
# ['bop', 'trade']
# ['castor-oil', 'oilseed', 'veg-oil']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['dlr', 'money-fx']
# ['rape-oil', 'veg-oil']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['gnp', 'money-fx']
# ['bop', 'trade']
# ['dfl', 'money-fx']
# ['dlr', 'money-fx']
# ['bop', 'trade']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['bop', 'trade']
# ['carcass', 'sugar']
# ['bop', 'trade']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['coffee', 'crude', 'grain', 'iron-steel', 'tea', 'trade', 'wheat']
# ['grain', 'wheat']
# ['crude', 'ship']
# ['dlr', 'money-fx']
# ['gold', 'lead', 'silver', 'zinc']
# ['corn', 'grain']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['corn', 'grain', 'rice', 'wheat']
# ['ipi', 'trade']
# ['gnp', 'reserves']
# ['crude', 'ship']
# ['gold', 'money-fx']
# ['cpi', 'crude', 'heat', 'nat-gas', 'propane']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['acq', 'ship']
# ['crude', 'ship']
# ['grain', 'ship']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['crude', 'ship']
# ['grain', 'trade']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['barley', 'grain', 'wheat']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['grain', 'wheat']
# ['dlr', 'money-fx', 'yen']
# ['corn', 'grain']
# ['oilseed', 'soybean']
# ['coconut', 'oilseed']
# ['dmk', 'money-fx', 'yen']
# ['coconut', 'oilseed']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'dmk', 'money-fx']
# ['oilseed', 'rape-oil', 'rapeseed', 'sun-oil', 'sunseed', 'veg-oil']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['money-fx', 'trade']
# ['money-fx', 'trade']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['ship', 'sugar']
# ['money-fx', 'yen']
# ['money-fx', 'trade']
# ['grain', 'rice', 'wheat']
# ['hog', 'livestock']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['pet-chem', 'rubber']
# ['grain', 'wheat']
# ['corn', 'grain', 'wheat']
# ['acq', 'gold']
# ['acq', 'gold']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['grain', 'wheat']
# ['oilseed', 'rapeseed']
# ['gnp', 'interest']
# ['corn', 'grain', 'wheat']
# ['corn', 'cotton', 'grain', 'sorghum', 'wheat']
# ['carcass', 'livestock', 'veg-oil']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['alum', 'earn', 'iron-steel']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['money-fx', 'yen']
# ['barley', 'grain', 'wheat']
# ['money-fx', 'trade']
# ['dlr', 'dmk', 'money-fx']
# ['acq', 'crude', 'sugar']
# ['grain', 'rice']
# ['cocoa', 'coffee', 'grain', 'rubber', 'sugar', 'tin', 'wheat']
# ['crude', 'nat-gas', 'sugar']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'trade', 'yen']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['money-fx', 'trade']
# ['corn', 'grain', 'sorghum']
# ['barley', 'grain', 'wheat']
# ['cocoa', 'coffee', 'sugar']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['gnp', 'lei']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['crude', 'earn']
# ['corn', 'grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['cocoa', 'coffee', 'sugar']
# ['crude', 'gas', 'heat']
# ['oilseed', 'rapeseed']
# ['grain', 'rice']
# ['interest', 'money-fx']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['grain', 'wheat']
# ['cotton', 'sorghum']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['crude', 'nat-gas']
# ['cotton', 'grain', 'rice']
# ['grain', 'wheat']
# ['grain', 'rice', 'wheat']
# ['cotton', 'grain', 'veg-oil', 'wheat']
# ['grain', 'ship', 'wheat']
# ['crude', 'gas']
# ['corn', 'grain']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['dlr', 'money-fx', 'yen']
# ['corn', 'cotton', 'grain']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['gnp', 'interest', 'money-fx']
# ['oilseed', 'palm-oil', 'palmkernel', 'veg-oil']
# ['dlr', 'money-fx']
# ['iron-steel', 'ship']
# ['grain', 'wheat']
# ['acq', 'coffee']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['coconut', 'oilseed']
# ['gold', 'silver']
# ['grain', 'meal-feed', 'oilseed', 'ship', 'veg-oil']
# ['dlr', 'money-fx']
# ['grain', 'wheat']
# ['gold', 'silver']
# ['gas', 'heat']
# ['bop', 'coffee', 'gnp']
# ['barley', 'corn', 'grain', 'oilseed', 'rapeseed', 'ship', 'wheat']
# ['grain', 'veg-oil', 'wheat']
# ['grain', 'oilseed', 'ship']
# ['hog', 'livestock']
# ['earn', 'iron-steel']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['dlr', 'dmk', 'money-fx']
# ['coffee', 'gnp']
# ['corn', 'grain', 'oilseed', 'soybean', 'sunseed']
# ['dlr', 'dmk', 'money-fx', 'nkr']
# ['oilseed', 'soybean']
# ['acq', 'strategic-metal']
# ['acq', 'earn']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['acq', 'strategic-metal']
# ['grain', 'wheat']
# ['corn', 'grain', 'sorghum']
# ['corn', 'grain']
# ['oilseed', 'rapeseed']
# ['grain', 'ship']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx', 'yen']
# ['corn', 'grain', 'meal-feed', 'soy-meal']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed']
# ['grain', 'ship']
# ['ship', 'sugar']
# ['interest', 'money-fx']
# ['grain', 'oilseed', 'soybean', 'wheat']
# ['cotton', 'grain', 'groundnut', 'oilseed', 'rapeseed', 'soybean', 'sunseed', 'wheat']
# ['carcass', 'livestock']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['groundnut', 'oilseed']
# ['corn', 'grain']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['grain', 'ship']
# ['dlr', 'interest']
# ['oilseed', 'soybean']
# ['meal-feed', 'soy-meal', 'sun-meal']
# ['grain', 'ship']
# ['crude', 'ship']
# ['carcass', 'corn', 'cotton', 'grain', 'groundnut', 'livestock', 'oilseed', 'sugar', 'veg-oil', 'wheat']
# ['carcass', 'livestock']
# ['dlr', 'interest', 'money-fx']
# ['cocoa', 'trade']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['money-fx', 'reserves']
# ['corn', 'grain', 'sorghum']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['oilseed', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil']
# ['barley', 'grain', 'wheat']
# ['money-supply', 'wpi']
# ['corn', 'grain']
# ['dlr', 'money-fx']
# ['oilseed', 'pet-chem']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['dlr', 'interest', 'money-fx', 'yen']
# ['interest', 'money-fx']
# ['alum', 'copper', 'lead', 'nickel', 'silver', 'zinc']
# ['interest', 'money-fx']
# ['corn', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['dlr', 'dmk', 'money-fx']
# ['crude', 'iron-steel']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'ship', 'wheat']
# ['gnp', 'money-supply']
# ['corn', 'grain']
# ['palm-oil', 'veg-oil']
# ['corn', 'grain']
# ['corn', 'grain']
# ['corn', 'grain']
# ['carcass', 'livestock', 'orange']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['palm-oil', 'veg-oil']
# ['meal-feed', 'soy-meal']
# ['oilseed', 'soybean']
# ['grain', 'wheat']
# ['grain', 'ship']
# ['pet-chem', 'ship']
# ['cpi', 'gnp', 'ipi']
# ['dlr', 'money-fx']
# ['soy-oil', 'veg-oil']
# ['meal-feed', 'soy-meal']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['gold', 'silver']
# ['money-fx', 'reserves']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['grain', 'ship']
# ['corn', 'grain']
# ['dlr', 'dmk', 'money-fx']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['oilseed', 'rapeseed']
# ['bop', 'gnp']
# ['coconut-oil', 'palm-oil', 'veg-oil']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['barley', 'grain']
# ['crude', 'nat-gas']
# ['grain', 'ship']
# ['grain', 'rice']
# ['grain', 'rice']
# ['nat-gas', 'propane']
# ['carcass', 'livestock']
# ['grain', 'ship']
# ['corn', 'grain', 'oilseed', 'soy-oil']
# ['corn', 'grain', 'oilseed', 'palm-oil', 'rapeseed', 'ship', 'soy-oil', 'wheat']
# ['grain', 'wheat']
# ['grain', 'rice']
# ['grain', 'oilseed', 'rapeseed', 'wheat']
# ['dlr', 'money-fx']
# ['carcass', 'livestock']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['crude', 'ship']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['corn', 'grain', 'sorghum']
# ['gold', 'reserves']
# ['carcass', 'livestock']
# ['grain', 'wheat']
# ['palm-oil', 'veg-oil']
# ['barley', 'wheat']
# ['grain', 'wheat']
# ['gold', 'reserves']
# ['barley', 'grain']
# ['dlr', 'money-fx']
# ['corn', 'wheat']
# ['barley', 'corn', 'grain', 'oat', 'sorghum', 'wheat']
# ['barley', 'corn', 'grain', 'sorghum', 'wheat']
# ['dlr', 'money-fx', 'trade']
# ['copper', 'zinc']
# ['grain', 'wheat']
# ['dlr', 'money-fx', 'trade']
# ['oilseed', 'soy-oil', 'soybean']
# ['dlr', 'dmk', 'money-fx']
# ['carcass', 'livestock']
# ['oilseed', 'soybean']
# ['money-fx', 'money-supply']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['crude', 'ship']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['money-fx', 'money-supply']
# ['cotton', 'grain', 'oat', 'oilseed', 'soybean', 'wheat']
# ['bop', 'trade']
# ['grain', 'wheat']
# ['money-fx', 'reserves']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['copper', 'nickel']
# ['grain', 'ship']
# ['livestock', 'sugar']
# ['corn', 'grain', 'livestock', 'oilseed']
# ['grain', 'ship', 'wheat']
# ['grain', 'veg-oil', 'wheat']
# ['grain', 'rice']
# ['copper', 'gold', 'lead', 'silver', 'zinc']
# ['oilseed', 'rapeseed']
# ['ship', 'sugar']
# ['grain', 'ship']
# ['crude', 'gas', 'heat']
# ['grain', 'ship']
# ['crude', 'gas']
# ['grain', 'oilseed', 'soybean']
# ['crude', 'ship']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['crude', 'fuel', 'gas']
# ['dlr', 'money-fx', 'yen']
# ['cpi', 'dlr', 'money-fx', 'money-supply', 'trade']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['carcass', 'grain', 'livestock']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed']
# ['cotton', 'grain', 'rice', 'wheat']
# ['copper', 'gold']
# ['bop', 'gnp', 'trade']
# ['grain', 'wheat']
# ['barley', 'corn', 'grain']
# ['fuel', 'gas']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['interest', 'money-fx']
# ['carcass', 'livestock', 'trade']
# ['corn', 'grain', 'wheat']
# ['cpi', 'gnp']
# ['grain', 'oilseed', 'soybean', 'wheat']
# ['grain', 'wheat']
# ['money-fx', 'trade']
# ['corn', 'grain', 'sorghum']
# ['crude', 'gas']
# ['crude', 'fuel', 'gas']
# ['acq', 'earn']
# ['crude', 'gas']
# ['cotton', 'grain', 'oilseed', 'rice', 'soybean']
# ['bop', 'trade']
# ['grain', 'wheat']
# ['grain', 'ship', 'wheat']
# ['crude', 'ship']
# ['grain', 'wheat']
# ['grain', 'rice']
# ['dlr', 'money-fx', 'yen']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['reserves', 'trade']
# ['gold', 'silver']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['bop', 'trade']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['corn', 'grain', 'oat']
# ['barley', 'carcass', 'grain', 'hog', 'livestock', 'meal-feed', 'potato', 'soy-meal', 'wheat']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['meal-feed', 'oilseed', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['barley', 'corn', 'grain', 'wheat']
# ['crude', 'earn']
# ['copper', 'grain', 'wheat']
# ['oilseed', 'soybean']
# ['cpi', 'gnp']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['barley', 'grain']
# ['barley', 'corn', 'grain', 'oilseed', 'rapeseed', 'wheat']
# ['money-fx', 'yen']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['copper', 'lead', 'strategic-metal', 'zinc']
# ['crude', 'ship']
# ['dlr', 'money-fx', 'yen']
# ['barley', 'grain', 'wheat']
# ['acq', 'earn']
# ['acq', 'sugar']
# ['gnp', 'jobs']
# ['interest', 'money-fx']
# ['barley', 'corn', 'grain', 'wheat']
# ['grain', 'wheat']
# ['carcass', 'hog', 'livestock']
# ['barley', 'grain']
# ['corn', 'grain']
# ['bop', 'gnp']
# ['gnp', 'trade']
# ['grain', 'rice']
# ['money-fx', 'yen']
# ['oilseed', 'soybean']
# ['dlr', 'money-fx']
# ['coffee', 'copra-cake', 'corn', 'cotton', 'grain', 'palm-oil', 'palmkernel', 'rice', 'rubber', 'soy-meal', 'soybean', 'sugar', 'tea', 'veg-oil', 'wheat']
# ['money-fx', 'trade']
# ['dlr', 'money-fx', 'yen']
# ['cotton', 'groundnut', 'oilseed', 'sugar', 'trade']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['carcass', 'l-cattle', 'livestock', 'sugar']
# ['grain', 'wheat']
# ['groundnut', 'veg-oil']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['corn', 'cotton', 'grain', 'meal-feed', 'oilseed', 'soy-meal', 'soy-oil', 'soybean', 'veg-oil']
# ['carcass', 'livestock']
# ['grain', 'wheat']
# ['crude', 'nat-gas', 'trade']
# ['crude', 'nat-gas']
# ['cocoa', 'coffee', 'oilseed', 'soybean', 'sugar', 'trade']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'trade', 'wheat']
# ['grain', 'wheat']
# ['hog', 'livestock']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['gnp', 'income', 'ipi', 'jobs', 'retail', 'trade']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['copra-cake', 'meal-feed']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['money-supply', 'reserves']
# ['interest', 'money-fx']
# ['gnp', 'interest']
# ['corn', 'grain']
# ['palm-oil', 'veg-oil']
# ['corn', 'grain', 'wheat']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['cocoa', 'coffee', 'tea']
# ['corn', 'grain', 'sugar']
# ['copper', 'gold', 'nickel', 'palladium', 'platinum']
# ['gas', 'ship']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['copper', 'gold', 'nickel', 'palladium', 'platinum']
# ['corn', 'grain', 'meal-feed']
# ['corn', 'grain']
# ['crude', 'interest']
# ['corn', 'grain']
# ['crude', 'fuel', 'jet']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['oilseed', 'soybean']
# ['cotton', 'grain', 'sugar', 'veg-oil']
# ['carcass', 'livestock']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['crude', 'nat-gas']
# ['crude', 'ship']
# ['bop', 'dlr', 'gnp', 'trade']
# ['dlr', 'interest', 'money-fx']
# ['bop', 'cpi', 'dfl', 'gnp', 'jobs']
# ['meal-feed', 'oilseed', 'soy-meal', 'soybean']
# ['gnp', 'money-fx']
# ['interest', 'money-fx']
# ['hog', 'livestock']
# ['interest', 'money-fx']
# ['bop', 'crude', 'dlr', 'gnp', 'money-fx', 'trade']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'dmk', 'money-fx']
# ['grain', 'oilseed']
# ['carcass', 'grain', 'livestock', 'meal-feed', 'soy-meal']
# ['gold', 'platinum', 'strategic-metal']
# ['bop', 'trade']
# ['acq', 'pet-chem']
# ['interest', 'money-fx']
# ['groundnut-oil', 'oilseed', 'palm-oil', 'rapeseed', 'soy-oil', 'soybean', 'sunseed', 'veg-oil']
# ['barley', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['corn', 'grain', 'wheat']
# ['crude', 'nat-gas']
# ['interest', 'money-fx']
# ['crude', 'nat-gas']
# ['acq', 'crude', 'nat-gas']
# ['corn', 'grain', 'sugar']
# ['palm-oil', 'rape-oil', 'veg-oil']
# ['oilseed', 'rapeseed']
# ['acq', 'earn']
# ['gnp', 'money-supply']
# ['acq', 'dlr', 'money-fx', 'trade']
# ['corn', 'grain', 'meal-feed', 'oilseed', 'rapeseed', 'soy-meal']
# ['grain', 'wheat']
# ['hog', 'l-cattle', 'livestock']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['interest', 'money-fx']
# ['corn', 'grain', 'oilseed', 'wheat']
# ['corn', 'grain']
# ['cocoa', 'coffee', 'heat', 'sugar']
# ['grain', 'wheat']
# ['carcass', 'hog', 'livestock']
# ['palm-oil', 'veg-oil']
# ['grain', 'wheat']
# ['barley', 'grain']
# ['corn', 'grain', 'wheat']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['bop', 'dlr', 'money-fx', 'trade']
# ['corn', 'grain', 'rice', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'ship']
# ['corn', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['cpi', 'gnp', 'money-fx']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx', 'yen']
# ['corn', 'grain', 'wheat']
# ['grain', 'rice', 'wheat']
# ['oilseed', 'soybean']
# ['copper', 'lead', 'zinc']
# ['oilseed', 'soybean']
# ['oilseed', 'soybean']
# ['interest', 'money-fx']
# ['earn', 'strategic-metal']
# ['palm-oil', 'veg-oil']
# ['bop', 'trade']
# ['interest', 'money-supply']
# ['money-fx', 'trade', 'yen']
# ['coconut-oil', 'oilseed', 'palm-oil', 'soybean', 'veg-oil']
# ['gold', 'silver']
# ['cpi', 'money-fx', 'reserves', 'trade']
# ['hog', 'livestock']
# ['bop', 'trade']
# ['copper', 'earn']
# ['bop', 'trade']
# ['gold', 'silver']
# ['crude', 'ship']
# ['sugar', 'trade']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['corn', 'grain']
# ['corn', 'gas', 'grain']
# ['copper', 'silver', 'zinc']
# ['acq', 'silver']
# ['crude', 'ship']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['carcass', 'livestock']
# ['grain', 'wheat']
# ['acq', 'crude']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['barley', 'corn', 'grain', 'wheat']
# ['rape-oil', 'sun-oil', 'veg-oil']
# ['coffee', 'ship']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['corn', 'grain', 'oilseed', 'sorghum', 'sunseed']
# ['crude', 'fuel', 'gas']
# ['interest', 'ipi', 'retail']
# ['crude', 'iron-steel', 'nat-gas']
# ['carcass', 'livestock']
# ['oilseed', 'rapeseed']
# ['corn', 'grain']
# ['iron-steel', 'ship']
# ['grain', 'wheat']
# ['acq', 'gold']
# ['oilseed', 'soybean']
# ['grain', 'sugar', 'wheat']
# ['bop', 'trade']
# ['oilseed', 'rapeseed', 'soybean', 'sunseed']
# ['interest', 'money-fx']
# ['money-fx', 'reserves']
# ['carcass', 'livestock']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['corn', 'grain', 'oilseed', 'orange', 'rice', 'soybean']
# ['palm-oil', 'veg-oil']
# ['cocoa', 'coffee']
# ['acq', 'trade']
# ['crude', 'nat-gas']
# ['grain', 'oat']
# ['crude', 'ship']
# ['interest', 'money-fx']
# ['grain', 'ship', 'wheat']
# ['hog', 'livestock']
# ['acq', 'ship']
# ['crude', 'earn', 'nat-gas']
# ['dlr', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['barley', 'grain']
# ['corn', 'grain']
# ['copper', 'earn']
# ['barley', 'corn', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['palm-oil', 'veg-oil']
# ['grain', 'rice']
# ['acq', 'crude']
# ['grain', 'wheat']
# ['acq', 'crude']
# ['corn', 'grain', 'wheat']
# ['oilseed', 'soybean']
# ['acq', 'ship']
# ['l-cattle', 'livestock']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['acq', 'gold', 'platinum']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['carcass', 'livestock']
# ['oilseed', 'rapeseed']
# ['carcass', 'livestock']
# ['cpi', 'gnp', 'reserves']
# ['cotton', 'grain', 'oilseed', 'rice', 'soybean', 'wheat']
# ['l-cattle', 'livestock']
# ['crude', 'nat-gas']
# ['cpi', 'gnp']
# ['carcass', 'livestock']
# ['crude', 'nat-gas']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['interest', 'money-supply']
# ['dlr', 'money-fx']
# ['bop', 'trade']
# ['carcass', 'livestock']
# ['money-fx', 'yen']
# ['carcass', 'livestock']
# ['palm-oil', 'veg-oil']
# ['grain', 'wheat']
# ['dlr', 'money-fx', 'yen']
# ['grain', 'rice']
# ['money-fx', 'yen']
# ['palm-oil', 'veg-oil']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['money-fx', 'yen']
# ['money-fx', 'yen']
# ['grain', 'rice']
# ['interest', 'money-fx']
# ['acq', 'earn']
# ['interest', 'money-fx']
# ['grain', 'ship']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['hog', 'livestock']
# ['gold', 'silver']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['corn', 'grain']
# ['gnp', 'interest', 'ipi', 'wpi']
# ['crude', 'nat-gas']
# ['crude', 'ship']
# ['crude', 'nat-gas']
# ['corn', 'grain']
# ['barley', 'corn', 'grain', 'oat', 'sorghum', 'wheat']
# ['corn', 'grain']
# ['carcass', 'livestock']
# ['barley', 'corn', 'grain', 'wheat']
# ['corn', 'grain']
# ['carcass', 'livestock']
# ['corn', 'grain']
# ['crude', 'gas', 'nat-gas', 'wpi']
# ['grain', 'wheat']
# ['crude', 'gas', 'heat', 'nat-gas', 'wpi']
# ['corn', 'grain']
# ['acq', 'crude']
# ['soy-oil', 'veg-oil']
# ['cpi', 'gas']
# ['crude', 'pet-chem']
# ['palm-oil', 'veg-oil']
# ['iron-steel', 'lead', 'zinc']
# ['crude', 'ship']
# ['corn', 'grain']
# ['trade', 'veg-oil']
# ['money-fx', 'reserves']
# ['corn', 'grain']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['money-fx', 'reserves']
# ['money-fx', 'yen']
# ['gnp', 'money-fx', 'yen']
# ['palm-oil', 'veg-oil']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['grain', 'rice']
# ['gnp', 'money-fx', 'yen']
# ['interest', 'money-fx']
# ['money-fx', 'reserves']
# ['money-fx', 'trade']
# ['trade', 'veg-oil']
# ['dlr', 'interest', 'money-fx']
# ['palm-oil', 'ship', 'veg-oil']
# ['palm-oil', 'veg-oil']
# ['hog', 'livestock']
# ['interest', 'money-fx']
# ['corn', 'grain', 'money-fx']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['oilseed', 'soybean', 'veg-oil']
# ['interest', 'money-fx']
# ['acq', 'copper']
# ['interest', 'money-fx']
# ['carcass', 'livestock']
# ['gnp', 'trade']
# ['barley', 'corn', 'cotton', 'grain', 'sorghum', 'wheat']
# ['carcass', 'livestock']
# ['corn', 'grain']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['crude', 'ship', 'trade']
# ['crude', 'ship']
# ['coffee', 'trade']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['barley', 'corn', 'cotton', 'grain', 'oilseed', 'rice', 'sorghum', 'soybean', 'wheat']
# ['crude', 'fuel', 'ship']
# ['meal-feed', 'veg-oil']
# ['corn', 'grain', 'sorghum', 'wheat']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['barley', 'grain']
# ['grain', 'wheat']
# ['crude', 'fuel']
# ['acq', 'nickel', 'strategic-metal']
# ['corn', 'grain']
# ['oilseed', 'soybean']
# ['oilseed', 'veg-oil']
# ['dlr', 'money-fx']
# ['bop', 'interest', 'money-fx', 'trade']
# ['bop', 'trade']
# ['bop', 'trade']
# ['soy-oil', 'veg-oil']
# ['carcass', 'livestock']
# ['interest', 'money-fx']
# ['interest', 'money-supply']
# ['money-fx', 'reserves']
# ['corn', 'grain']
# ['crude', 'ship', 'trade']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['carcass', 'l-cattle', 'livestock']
# ['corn', 'grain']
# ['bop', 'trade']
# ['bop', 'trade']
# ['bop', 'trade']
# ['corn', 'grain', 'lin-oil', 'oilseed', 'sorghum', 'soy-oil', 'soybean', 'sun-oil', 'sunseed', 'veg-oil', 'wheat']
# ['grain', 'wheat']
# ['bop', 'gnp']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['soybean', 'veg-oil']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['grain', 'rice', 'wheat']
# ['oilseed', 'soybean']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['grain', 'rice', 'wheat']
# ['bop', 'interest', 'money-supply']
# ['ipi', 'jobs']
# ['gnp', 'housing', 'interest']
# ['grain', 'wheat']
# ['corn', 'grain', 'wheat']
# ['corn', 'grain']
# ['corn', 'wheat']
# ['grain', 'trade']
# ['corn', 'grain', 'wheat']
# ['grain', 'oilseed', 'soybean']
# ['carcass', 'corn', 'cotton', 'grain', 'oilseed', 'rice', 'soybean']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['money-fx', 'yen']
# ['grain', 'wheat']
# ['palm-oil', 'veg-oil']
# ['palm-oil', 'veg-oil']
# ['palm-oil', 'veg-oil']
# ['money-fx', 'yen']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['bop', 'cpi', 'gnp', 'interest', 'trade']
# ['cotton-oil', 'sun-oil', 'veg-oil']
# ['coconut-oil', 'veg-oil']
# ['interest', 'money-fx']
# ['lead', 'zinc']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['cotton', 'iron-steel', 'naphtha', 'palm-oil', 'trade', 'veg-oil']
# ['interest', 'money-fx']
# ['corn', 'grain', 'veg-oil']
# ['corn', 'grain', 'ship']
# ['gnp', 'trade']
# ['bop', 'trade']
# ['crude', 'nat-gas']
# ['barley', 'grain']
# ['bop', 'trade']
# ['crude', 'ship']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['corn', 'grain']
# ['crude', 'earn', 'nat-gas']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['crude', 'gas']
# ['crude', 'nat-gas']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed']
# ['crude', 'gas']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['meal-feed', 'oilseed', 'soy-meal', 'soybean', 'veg-oil']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['oilseed', 'soybean']
# ['grain', 'wheat']
# ['corn', 'grain', 'oilseed', 'soybean', 'wheat']
# ['money-fx', 'nzdlr']
# ['grain', 'wheat']
# ['bop', 'palm-oil', 'rubber', 'trade', 'veg-oil']
# ['bop', 'gnp', 'trade']
# ['grain', 'wheat']
# ['soy-oil', 'veg-oil']
# ['income', 'money-fx', 'money-supply']
# ['oilseed', 'soybean', 'veg-oil']
# ['money-fx', 'rand']
# ['corn', 'grain', 'wheat']
# ['crude', 'nat-gas']
# ['hog', 'livestock']
# ['grain', 'ship']
# ['crude', 'gas']
# ['crude', 'gas']
# ['interest', 'money-fx']
# ['grain', 'rice']
# ['crude', 'earn', 'nat-gas']
# ['barley', 'corn', 'grain', 'wheat']
# ['interest', 'money-fx']
# ['corn', 'grain', 'wheat']
# ['acq', 'earn']
# ['interest', 'money-fx', 'money-supply']
# ['grain', 'wheat']
# ['corn', 'grain']
# ['oilseed', 'soybean']
# ['money-fx', 'trade']
# ['corn', 'grain']
# ['corn', 'grain']
# ['corn', 'grain']
# ['corn', 'grain']
# ['fuel', 'heat', 'jet', 'naphtha']
# ['grain', 'wheat']
# ['crude', 'nat-gas']
# ['interest', 'money-fx']
# ['grain', 'wheat']
# ['interest', 'money-supply']
# ['oilseed', 'soybean', 'veg-oil']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['grain', 'rice', 'sugar', 'tea', 'wheat']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['grain', 'meal-feed']
# ['interest', 'money-fx']
# ['barley', 'grain']
# ['interest', 'money-fx', 'money-supply']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['oilseed', 'soybean', 'veg-oil']
# ['money-fx', 'trade']
# ['bop', 'trade']
# ['cotton', 'iron-steel', 'trade']
# ['gold', 'silver']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['interest', 'money-fx']
# ['crude', 'earn']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['copper', 'gold', 'lead', 'silver', 'strategic-metal', 'zinc']
# ['corn', 'grain', 'ship']
# ['money-fx', 'trade']
# ['lead', 'zinc']
# ['crude', 'gas']
# ['acq', 'earn']
# ['acq', 'earn']
# ['acq', 'earn']
# ['corn', 'cotton', 'grain', 'rice']
# ['acq', 'earn']
# ['corn', 'grain', 'wheat']
# ['corn', 'grain']
# ['meal-feed', 'oilseed']
# ['grain', 'wheat']
# ['acq', 'ship']
# ['hog', 'livestock']
# ['grain', 'oilseed', 'soybean', 'veg-oil', 'wheat']
# ['corn', 'grain', 'sugar']
# ['grain', 'ship']
# ['crude', 'fuel', 'nat-gas']
# ['dlr', 'money-fx']
# ['acq', 'crude', 'nat-gas']
# ['coconut', 'oilseed']
# ['grain', 'oilseed', 'trade']
# ['gnp', 'interest', 'trade']
# ['corn', 'grain', 'meal-feed', 'oilseed', 'sorghum', 'soybean']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['coffee', 'palm-oil', 'rubber', 'trade']
# ['gnp', 'interest', 'money-fx', 'trade']
# ['trade', 'veg-oil']
# ['reserves', 'trade']
# ['palm-oil', 'rape-oil', 'ship', 'veg-oil']
# ['corn', 'grain', 'rice']
# ['cpi', 'gnp', 'grain', 'reserves']
# ['acq', 'corn', 'grain']
# ['interest', 'money-fx']
# ['gnp', 'jobs', 'retail', 'trade']
# ['bop', 'trade']
# ['grain', 'wheat']
# ['interest', 'money-fx']
# ['crude', 'ship']
# ['dlr', 'money-fx', 'trade']
# ['interest', 'money-fx']
# ['coffee', 'ship']
# ['crude', 'nat-gas']
# ['barley', 'grain', 'oilseed', 'rapeseed']
# ['interest', 'money-fx']
# ['barley', 'corn', 'grain']
# ['corn', 'cotton', 'grain', 'oilseed', 'trade', 'wheat']
# ['acq', 'crude']
# ['gas', 'heat', 'propane']
# ['interest', 'money-fx']
# ['grain', 'oilseed', 'ship']
# ['oilseed', 'soy-oil', 'soybean', 'veg-oil']
# ['corn', 'grain']
# ['cotton', 'grain', 'rice', 'wheat']
# ['crude', 'ship']
# ['gnp', 'trade']
# ['crude', 'ship']
# ['corn', 'grain', 'oilseed']
# ['corn', 'grain', 'sorghum']
# ['crude', 'ship']
# ['oilseed', 'soybean']
# ['corn', 'grain', 'wheat']
# ['corn', 'grain', 'oat', 'oilseed', 'soybean']
# ['grain', 'wheat']
# ['acq', 'earn']
# ['carcass', 'livestock']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['coconut-oil', 'trade', 'veg-oil']
# ['money-fx', 'reserves', 'trade']
# ['crude', 'earn']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['crude', 'earn', 'nat-gas']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['ipi', 'trade']
# ['crude', 'ship']
# ['cpi', 'wpi']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx', 'yen']
# ['interest', 'money-fx', 'money-supply']
# ['dlr', 'money-fx']
# ['grain', 'wheat']
# ['livestock', 'ship']
# ['cpi', 'gnp', 'jobs', 'retail', 'trade']
# ['crude', 'ship']
# ['barley', 'corn', 'cotton', 'grain', 'oat', 'rice', 'sorghum', 'wheat']
# ['acq', 'ship']
# ['carcass', 'grain', 'livestock', 'sugar']
# ['crude', 'nat-gas']
# ['crude', 'nat-gas']
# ['crude', 'earn', 'nat-gas']
# ['palm-oil', 'veg-oil']
# ['acq', 'gold', 'lead', 'silver', 'zinc']
# ['crude', 'ship']
# ['acq', 'gold', 'lead', 'silver', 'zinc']
# ['crude', 'gas']
# ['interest', 'money-fx']
# ['earn', 'ship']
# ['money-fx', 'trade']
# ['corn', 'grain']
# ['coffee', 'ship']
# ['crude', 'earn']
# ['crude', 'earn', 'gas']
# ['crude', 'earn', 'pet-chem']
# ['acq', 'earn']
# ['corn', 'grain']
# ['corn', 'grain', 'wheat']
# ['money-fx', 'trade']
# ['grain', 'rice']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['acq', 'earn']
# ['crude', 'gas']
# ['dlr', 'money-fx']
# ['money-fx', 'trade']
# ['corn', 'grain', 'oilseed', 'soybean']
# ['carcass', 'hog', 'livestock', 'trade']
# ['dlr', 'money-fx']
# ['nat-gas', 'pet-chem']
# ['dlr', 'money-fx']
# ['corn', 'grain']
# ['corn', 'grain']
# ['grain', 'wheat']
# ['acq', 'earn']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['money-fx', 'yen']
# ['coffee', 'rubber', 'tea']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['sun-oil', 'veg-oil']
# ['copper', 'silver']
# ['alum', 'earn']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx', 'yen']
# ['dlr', 'money-fx']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['dlr', 'money-fx']
# ['orange', 'tea']
# ['corn', 'grain']
# ['interest', 'money-fx']
# ['ship', 'sugar']
# ['dlr', 'money-fx']
# ['alum', 'earn']
# ['grain', 'trade']
# ['interest', 'money-fx']
# ['interest', 'money-fx']
# ['crude', 'nat-gas']
# ['palm-oil', 'veg-oil']
# ['corn', 'grain', 'sugar']
# ['money-fx', 'trade']
# ['corn', 'grain', 'oilseed', 'sorghum', 'soybean', 'sunseed']
# ['interest', 'money-fx']
# ['crude', 'nat-gas']
# ['hog', 'livestock']
# ['iron-steel', 'trade']
# ['crude', 'gas']
# ['oilseed', 'soybean']
# ['crude', 'gas']
# ['crude', 'nat-gas']
# ['crude', 'nat-gas']
# ['interest', 'money-fx']
# ['corn', 'grain']
# ['money-fx', 'yen']
# ['corn', 'grain', 'oat', 'oilseed', 'rye', 'sorghum', 'soybean', 'wheat']
# ['interest', 'money-fx', 'yen']
# ['grain', 'rice']
# ['crude', 'ship']
# ['bop', 'trade']
# ['interest', 'money-fx']
# ['bop', 'trade']
# ['jobs', 'trade']
# ['carcass', 'livestock']
# ['meal-feed', 'oilseed', 'veg-oil']
# ['bop', 'trade']
# ['bop', 'trade']
# ['grain', 'wheat']
# ['grain', 'wheat']
# ['dlr', 'money-fx']
# ['bop', 'interest', 'money-fx', 'trade']
# ['grain', 'wheat']
# ['crude', 'ship']
# ['bop', 'trade']
# ['bop', 'trade']
# ['bop', 'trade']
# ['bop', 'interest', 'money-fx', 'trade']
# ['crude', 'trade']
# ['interest', 'money-fx']
# ['dlr', 'money-fx']
# ['money-fx', 'trade']
# ['barley', 'corn', 'grain', 'wheat']
# ['dlr', 'money-fx']
# ['crude', 'earn']
# ['jobs', 'trade']
# ['acq', 'crude']
# ['oilseed', 'soybean']
# ['dlr', 'money-fx', 'yen']
# ['acq', 'crude']
# ['money-fx', 'trade']
# ['barley', 'corn', 'grain']
# ['corn', 'grain']
# ['interest', 'money-fx']
# Success! Data saved to data/rcv1/rcv1.csv
