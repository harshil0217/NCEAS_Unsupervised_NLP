# %% [markdown]
# # arXiv Qwen3 Embeddings (Phase 2.2)
#
# This notebook generates open-source embeddings for the arXiv 30k dataset using:
#
# Model: Qwen/Qwen3-Embedding-0.6B
# Framework: SentenceTransformers
#
# This replaces OpenAI embeddings to ensure full reproducibility.

# %%
import os
import warnings
import numpy as np
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer

warnings.filterwarnings("ignore")
np.random.seed(42)

# %%
dataset_name = "arxiv"
embedding_model = "Qwen3-Embedding-0.6B"

DATA_PATH = "arxiv_30k_clean.csv"
OUTPUT_DIR = "data/embeddings"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
print("Loading dataset...")
df = pd.read_csv(DATA_PATH)

texts = df["text"].astype(str).tolist()

print("Number of documents:", len(texts))
df.head()
# Out:
# Loading dataset...
# Number of documents: 30000
#                                                 text           label
# 0  GenS: Generalizable Neural Surface Reconstruct...           cs.CV
# 1  Game-Theoretic and Machine Learning-based Appr...           cs.CR
# 2  Raman Beam Cleanup in Silicon in the Mid-Infra...  physics.optics
# 3  Complex event recognition under time constrain...           cs.DB
# 4  Visual Search at Pinterest   We demonstrate th...           cs.CV

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

model = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B", device=device)
# Out:
# Using device: cpu
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]

# %%
print("Generating embeddings...")

embeddings = model.encode(
    texts,
    batch_size=32,
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
)

print("Embedding shape:", embeddings.shape)
# Out:
# Generating embeddings...
# Batches:   0%|          | 0/938 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 print("Generating embeddings...")
# ----> 3 embeddings = model.encode(
#       4     texts,
#       5     batch_size=32,
#       6     show_progress_bar=True,
#       7     convert_to_numpy=True,
#       8     normalize_embeddings=True
#       9 )
#      11 print("Embedding shape:", embeddings.shape)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/sentence_transformers/SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/sentence_transformers/SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/sentence_transformers/models/Transformer.py:262, in Transformer.forward(self, features, **kwargs)
#     239 """
#     240 Forward pass through the transformer model.
#     241
#    (...)    258         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     259 """
#     260 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 262 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     263 token_embeddings = outputs[0]
#     264 features["token_embeddings"] = token_embeddings
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/utils/generic.py:915, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     913             output = func(self, *args, **kwargs)
#     914     else:
# --> 915         output = func(self, *args, **kwargs)
#     916 # Restore original config value
#     917 finally:
#     918     if is_causal is not None:
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/utils/output_capturing.py:253, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     251 # Run the forward
#     252 try:
# --> 253     outputs = func(self, *args, **kwargs)
#     254 # Reset the states
#     255 finally:
#     256     _active_collector.reset(output_token)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/models/qwen3/modeling_qwen3.py:436, in Qwen3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     433 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     435 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 436     hidden_states = decoder_layer(
#     437         hidden_states,
#     438         attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#     439         position_embeddings=position_embeddings,
#     440         position_ids=position_ids,
#     441         past_key_values=past_key_values,
#     442         use_cache=use_cache,
#     443         cache_position=cache_position,
#     444         **kwargs,
#     445     )
#     447 hidden_states = self.norm(hidden_states)
#     448 return BaseModelOutputWithPast(
#     449     last_hidden_state=hidden_states,
#     450     past_key_values=past_key_values if use_cache else None,
#     451 )
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/modeling_layers.py:93, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      90         logger.warning_once(message)
#      92     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93 return super().__call__(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/models/qwen3/modeling_qwen3.py:323, in Qwen3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     321 hidden_states = self.input_layernorm(hidden_states)
#     322 # Self Attention
# --> 323 hidden_states, _ = self.self_attn(
#     324     hidden_states=hidden_states,
#     325     attention_mask=attention_mask,
#     326     position_ids=position_ids,
#     327     past_key_values=past_key_values,
#     328     use_cache=use_cache,
#     329     cache_position=cache_position,
#     330     position_embeddings=position_embeddings,
#     331     **kwargs,
#     332 )
#     333 hidden_states = residual + hidden_states
#     335 # Fully Connected
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/models/qwen3/modeling_qwen3.py:280, in Qwen3Attention.forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     274     key_states, value_states = past_key_values.update(key_states, value_states, self.layer_idx, cache_kwargs)
#     276 attention_interface: Callable = ALL_ATTENTION_FUNCTIONS.get_interface(
#     277     self.config._attn_implementation, eager_attention_forward
#     278 )
# --> 280 attn_output, attn_weights = attention_interface(
#     281     self,
#     282     query_states,
#     283     key_states,
#     284     value_states,
#     285     attention_mask,
#     286     dropout=0.0 if not self.training else self.attention_dropout,
#     287     scaling=self.scaling,
#     288     sliding_window=self.sliding_window,  # diff with Llama
#     289     **kwargs,
#     290 )
#     292 attn_output = attn_output.reshape(*input_shape, -1).contiguous()
#     293 attn_output = self.o_proj(attn_output)
#
# File ~/NCEAS_Unsupervised_NLP/.venv/lib/python3.13/site-packages/transformers/integrations/sdpa_attention.py:92, in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, **kwargs)
#      88     if attention_mask is not None and attention_mask.dtype != torch.bool:
#      89         # Convert to boolean type, making sdpa to force call FlashAttentionScore to improve performance.
#      90         attention_mask = torch.logical_not(attention_mask.bool()).to(query.device)
# ---> 92 attn_output = torch.nn.functional.scaled_dot_product_attention(
#      93     query,
#      94     key,
#      95     value,
#      96     attn_mask=attention_mask,
#      97     dropout_p=dropout,
#      98     scale=scaling,
#      99     is_causal=is_causal,
#     100     **sdpa_kwargs,
#     101 )
#     102 attn_output = attn_output.transpose(1, 2).contiguous()
#     104 return attn_output, None
#
# KeyboardInterrupt:

# %%
np.save(
    os.path.join(OUTPUT_DIR, "arxiv_qwen3_embeddings.npy"),
    embeddings
)

df.to_csv(
    os.path.join(OUTPUT_DIR, "arxiv_qwen3_metadata.csv"),
    index=False
)

print("Saved embeddings and metadata.")
